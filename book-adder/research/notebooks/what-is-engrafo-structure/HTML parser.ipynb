# %%
import xml

# %%
from html.parser import HTMLParser

# %%
class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print("Start tag:", tag)
        for attr in attrs:
            print("     attr:", attr)

    def handle_endtag(self, tag):
        print("End tag  :", tag)

    def handle_data(self, data):
        print("Data     :", data)

    def handle_comment(self, data):
        print("Comment  :", data)

    def handle_entityref(self, name):
        c = chr(name2codepoint[name])
        print("Named ent:", c)

    def handle_charref(self, name):
        if name.startswith('x'):
            c = chr(int(name[1:], 16))
        else:
            c = chr(int(name))
        print("Num ent  :", c)

    def handle_decl(self, data):
        print("Decl     :", data)

parser = MyHTMLParser()

# %%
with open("./assets/index.html","r") as f:
    html_string = f.read()

# %%
parser.feed(html_string)
# Out:
# Decl     : DOCTYPE html
# Start tag: html
# Start tag: head
# Data     :
#
# Start tag: title
# Data     : Quantum black holes, partition of integers and self-similarity
# End tag  : title
# Data     :
#
# Comment  : Generated by LaTeXML (version 0.8.4) http://dlmf.nist.gov/LaTeXML/.
# Data     :
#
#
# Start tag: meta
#      attr: ('http-equiv', 'Content-Type')
#      attr: ('content', 'text/html; charset=UTF-8')
# Data     :
#
# Start tag: link
#      attr: ('rel', 'stylesheet')
#      attr: ('href', '/app/dist/css/index.css')
#      attr: ('type', 'text/css')
# Data     :
#
#
# Start tag: meta
#      attr: ('name', 'viewport')
#      attr: ('content', 'width=device-width, initial-scale=1, shrink-to-fit=no')
# Start tag: style
#      attr: ('type', 'text/css')
# Data     : .mjx-chtml {display: inline-block; line-height: 0; text-indent: 0; text-align: left; text-transform: none; font-style: normal; font-weight: normal; font-size: 100%; font-size-adjust: none; letter-spacing: normal; word-wrap: normal; word-spacing: normal; white-space: nowrap; float: none; direction: ltr; max-width: none; max-height: none; min-width: 0; min-height: 0; border: 0; margin: 0; padding: 1px 0}
# .MJXc-display {display: block; text-align: center; margin: 1em 0; padding: 0}
# .mjx-chtml[tabindex]:focus, body :focus .mjx-chtml[tabindex] {display: inline-table}
# .mjx-full-width {text-align: center; display: table-cell!important; width: 10000em}
# .mjx-math {display: inline-block; border-collapse: separate; border-spacing: 0}
# .mjx-math * {display: inline-block; -webkit-box-sizing: content-box!important; -moz-box-sizing: content-box!important; box-sizing: content-box!important; text-align: left}
# .mjx-numerator {display: block; text-align: center}
# .mjx-denominator {display: block; text-align: center}
# .MJXc-stacked {height: 0; position: relative}
# .MJXc-stacked > * {position: absolute}
# .MJXc-bevelled > * {display: inline-block}
# .mjx-stack {display: inline-block}
# .mjx-op {display: block}
# .mjx-under {display: table-cell}
# .mjx-over {display: block}
# .mjx-over > * {padding-left: 0px!important; padding-right: 0px!important}
# .mjx-under > * {padding-left: 0px!important; padding-right: 0px!important}
# .mjx-stack > .mjx-sup {display: block}
# .mjx-stack > .mjx-sub {display: block}
# .mjx-prestack > .mjx-presup {display: block}
# .mjx-prestack > .mjx-presub {display: block}
# .mjx-delim-h > .mjx-char {display: inline-block}
# .mjx-surd {vertical-align: top}
# .mjx-mphantom * {visibility: hidden}
# .mjx-merror {background-color: #FFFF88; color: #CC0000; border: 1px solid #CC0000; padding: 2px 3px; font-style: normal; font-size: 90%}
# .mjx-annotation-xml {line-height: normal}
# .mjx-menclose > svg {fill: none; stroke: currentColor}
# .mjx-mtr {display: table-row}
# .mjx-mlabeledtr {display: table-row}
# .mjx-mtd {display: table-cell; text-align: center}
# .mjx-label {display: table-row}
# .mjx-box {display: inline-block}
# .mjx-block {display: block}
# .mjx-span {display: inline}
# .mjx-char {display: block; white-space: pre}
# .mjx-itable {display: inline-table; width: auto}
# .mjx-row {display: table-row}
# .mjx-cell {display: table-cell}
# .mjx-table {display: table; width: 100%}
# .mjx-line {display: block; height: 0}
# .mjx-strut {width: 0; padding-top: 1em}
# .mjx-vsize {width: 0}
# .MJXc-space1 {margin-left: .167em}
# .MJXc-space2 {margin-left: .222em}
# .MJXc-space3 {margin-left: .278em}
# .mjx-test.mjx-test-display {display: table!important}
# .mjx-test.mjx-test-inline {display: inline!important; margin-right: -1px}
# .mjx-test.mjx-test-default {display: block!important; clear: both}
# .mjx-ex-box {display: inline-block!important; position: absolute; overflow: hidden; min-height: 0; max-height: none; padding: 0; border: 0; margin: 0; width: 1px; height: 60ex}
# .mjx-test-inline .mjx-left-box {display: inline-block; width: 0; float: left}
# .mjx-test-inline .mjx-right-box {display: inline-block; width: 0; float: right}
# .mjx-test-display .mjx-right-box {display: table-cell!important; width: 10000em!important; min-width: 0; max-width: none; padding: 0; border: 0; margin: 0}
# .MJXc-TeX-unknown-R {font-family: monospace; font-style: normal; font-weight: normal}
# .MJXc-TeX-unknown-I {font-family: monospace; font-style: italic; font-weight: normal}
# .MJXc-TeX-unknown-B {font-family: monospace; font-style: normal; font-weight: bold}
# .MJXc-TeX-unknown-BI {font-family: monospace; font-style: italic; font-weight: bold}
# .MJXc-TeX-ams-R {font-family: MJXc-TeX-ams-R,MJXc-TeX-ams-Rw}
# .MJXc-TeX-cal-B {font-family: MJXc-TeX-cal-B,MJXc-TeX-cal-Bx,MJXc-TeX-cal-Bw}
# .MJXc-TeX-frak-R {font-family: MJXc-TeX-frak-R,MJXc-TeX-frak-Rw}
# .MJXc-TeX-frak-B {font-family: MJXc-TeX-frak-B,MJXc-TeX-frak-Bx,MJXc-TeX-frak-Bw}
# .MJXc-TeX-math-BI {font-family: MJXc-TeX-math-BI,MJXc-TeX-math-BIx,MJXc-TeX-math-BIw}
# .MJXc-TeX-sans-R {font-family: MJXc-TeX-sans-R,MJXc-TeX-sans-Rw}
# .MJXc-TeX-sans-B {font-family: MJXc-TeX-sans-B,MJXc-TeX-sans-Bx,MJXc-TeX-sans-Bw}
# .MJXc-TeX-sans-I {font-family: MJXc-TeX-sans-I,MJXc-TeX-sans-Ix,MJXc-TeX-sans-Iw}
# .MJXc-TeX-script-R {font-family: MJXc-TeX-script-R,MJXc-TeX-script-Rw}
# .MJXc-TeX-type-R {font-family: MJXc-TeX-type-R,MJXc-TeX-type-Rw}
# .MJXc-TeX-cal-R {font-family: MJXc-TeX-cal-R,MJXc-TeX-cal-Rw}
# .MJXc-TeX-main-B {font-family: MJXc-TeX-main-B,MJXc-TeX-main-Bx,MJXc-TeX-main-Bw}
# .MJXc-TeX-main-I {font-family: MJXc-TeX-main-I,MJXc-TeX-main-Ix,MJXc-TeX-main-Iw}
# .MJXc-TeX-main-R {font-family: MJXc-TeX-main-R,MJXc-TeX-main-Rw}
# .MJXc-TeX-math-I {font-family: MJXc-TeX-math-I,MJXc-TeX-math-Ix,MJXc-TeX-math-Iw}
# .MJXc-TeX-size1-R {font-family: MJXc-TeX-size1-R,MJXc-TeX-size1-Rw}
# .MJXc-TeX-size2-R {font-family: MJXc-TeX-size2-R,MJXc-TeX-size2-Rw}
# .MJXc-TeX-size3-R {font-family: MJXc-TeX-size3-R,MJXc-TeX-size3-Rw}
# .MJXc-TeX-size4-R {font-family: MJXc-TeX-size4-R,MJXc-TeX-size4-Rw}
# .MJXc-TeX-vec-R {font-family: MJXc-TeX-vec-R,MJXc-TeX-vec-Rw}
# .MJXc-TeX-vec-B {font-family: MJXc-TeX-vec-B,MJXc-TeX-vec-Bx,MJXc-TeX-vec-Bw}
# @font-face {font-family: MJXc-TeX-ams-R; src: local('MathJax_AMS'), local('MathJax_AMS-Regular')}
# @font-face {font-family: MJXc-TeX-ams-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_AMS-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_AMS-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_AMS-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-cal-B; src: local('MathJax_Caligraphic Bold'), local('MathJax_Caligraphic-Bold')}
# @font-face {font-family: MJXc-TeX-cal-Bx; src: local('MathJax_Caligraphic'); font-weight: bold}
# @font-face {font-family: MJXc-TeX-cal-Bw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Caligraphic-Bold.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Caligraphic-Bold.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Caligraphic-Bold.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-frak-R; src: local('MathJax_Fraktur'), local('MathJax_Fraktur-Regular')}
# @font-face {font-family: MJXc-TeX-frak-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Fraktur-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Fraktur-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Fraktur-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-frak-B; src: local('MathJax_Fraktur Bold'), local('MathJax_Fraktur-Bold')}
# @font-face {font-family: MJXc-TeX-frak-Bx; src: local('MathJax_Fraktur'); font-weight: bold}
# @font-face {font-family: MJXc-TeX-frak-Bw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Fraktur-Bold.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Fraktur-Bold.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Fraktur-Bold.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-math-BI; src: local('MathJax_Math BoldItalic'), local('MathJax_Math-BoldItalic')}
# @font-face {font-family: MJXc-TeX-math-BIx; src: local('MathJax_Math'); font-weight: bold; font-style: italic}
# @font-face {font-family: MJXc-TeX-math-BIw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Math-BoldItalic.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Math-BoldItalic.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Math-BoldItalic.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-sans-R; src: local('MathJax_SansSerif'), local('MathJax_SansSerif-Regular')}
# @font-face {font-family: MJXc-TeX-sans-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_SansSerif-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_SansSerif-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_SansSerif-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-sans-B; src: local('MathJax_SansSerif Bold'), local('MathJax_SansSerif-Bold')}
# @font-face {font-family: MJXc-TeX-sans-Bx; src: local('MathJax_SansSerif'); font-weight: bold}
# @font-face {font-family: MJXc-TeX-sans-Bw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_SansSerif-Bold.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_SansSerif-Bold.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_SansSerif-Bold.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-sans-I; src: local('MathJax_SansSerif Italic'), local('MathJax_SansSerif-Italic')}
# @font-face {font-family: MJXc-TeX-sans-Ix; src: local('MathJax_SansSerif'); font-style: italic}
# @font-face {font-family: MJXc-TeX-sans-Iw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_SansSerif-Italic.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_SansSerif-Italic.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_SansSerif-Italic.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-script-R; src: local('MathJax_Script'), local('MathJax_Script-Regular')}
# @font-face {font-family: MJXc-TeX-script-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Script-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Script-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Script-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-type-R; src: local('MathJax_Typewriter'), local('MathJax_Typewriter-Regular')}
# @font-face {font-family: MJXc-TeX-type-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Typewriter-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Typewriter-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Typewriter-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-cal-R; src: local('MathJax_Caligraphic'), local('MathJax_Caligraphic-Regular')}
# @font-face {font-family: MJXc-TeX-cal-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Caligraphic-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Caligraphic-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Caligraphic-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-main-B; src: local('MathJax_Main Bold'), local('MathJax_Main-Bold')}
# @font-face {font-family: MJXc-TeX-main-Bx; src: local('MathJax_Main'); font-weight: bold}
# @font-face {font-family: MJXc-TeX-main-Bw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Main-Bold.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Main-Bold.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Main-Bold.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-main-I; src: local('MathJax_Main Italic'), local('MathJax_Main-Italic')}
# @font-face {font-family: MJXc-TeX-main-Ix; src: local('MathJax_Main'); font-style: italic}
# @font-face {font-family: MJXc-TeX-main-Iw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Main-Italic.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Main-Italic.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Main-Italic.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-main-R; src: local('MathJax_Main'), local('MathJax_Main-Regular')}
# @font-face {font-family: MJXc-TeX-main-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Main-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Main-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Main-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-math-I; src: local('MathJax_Math Italic'), local('MathJax_Math-Italic')}
# @font-face {font-family: MJXc-TeX-math-Ix; src: local('MathJax_Math'); font-style: italic}
# @font-face {font-family: MJXc-TeX-math-Iw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Math-Italic.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Math-Italic.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Math-Italic.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-size1-R; src: local('MathJax_Size1'), local('MathJax_Size1-Regular')}
# @font-face {font-family: MJXc-TeX-size1-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Size1-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Size1-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Size1-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-size2-R; src: local('MathJax_Size2'), local('MathJax_Size2-Regular')}
# @font-face {font-family: MJXc-TeX-size2-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Size2-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Size2-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Size2-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-size3-R; src: local('MathJax_Size3'), local('MathJax_Size3-Regular')}
# @font-face {font-family: MJXc-TeX-size3-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Size3-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Size3-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Size3-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-size4-R; src: local('MathJax_Size4'), local('MathJax_Size4-Regular')}
# @font-face {font-family: MJXc-TeX-size4-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Size4-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Size4-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Size4-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-vec-R; src: local('MathJax_Vector'), local('MathJax_Vector-Regular')}
# @font-face {font-family: MJXc-TeX-vec-Rw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Vector-Regular.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Vector-Regular.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Vector-Regular.otf') format('opentype')}
# @font-face {font-family: MJXc-TeX-vec-B; src: local('MathJax_Vector Bold'), local('MathJax_Vector-Bold')}
# @font-face {font-family: MJXc-TeX-vec-Bx; src: local('MathJax_Vector'); font-weight: bold}
# @font-face {font-family: MJXc-TeX-vec-Bw; src /*1*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/eot/MathJax_Vector-Bold.eot'); src /*2*/: url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/woff/MathJax_Vector-Bold.woff') format('woff'), url('https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.2/fonts/HTML-CSS/TeX/otf/MathJax_Vector-Bold.otf') format('opentype')}
#
# End tag  : style
# End tag  : head
# Data     :
#
# Start tag: body
# Data     :
#
# Start tag: div
#      attr: ('class', 'ltx_page_main')
# Data     :
#
# Start tag: div
#      attr: ('class', 'ltx_page_content')
# Data     :
#
# Start tag: article
#      attr: ('class', 'ltx_document ltx_authors_1line')
# Data     :
#
# Start tag: h1
#      attr: ('class', 'ltx_title ltx_title_document')
# Data     : Quantum black holes, partition of integers and self-similarity
# End tag  : h1
# Data     :
#
# Start tag: div
#      attr: ('class', 'ltx_authors')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_creator ltx_role_author')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_personname')
# Data     : P. Castorina
# Start tag: span
#      attr: ('id', 'm1')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(a,b)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : a
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'margin-top: -0.144em; padding-bottom: 0.519em;')
# Data     : ,
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : b
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : , A Iorio
# Start tag: span
#      attr: ('id', 'm2')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(a)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : a
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :  and L. Smaldone
# Start tag: span
#      attr: ('id', 'm3')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(c)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : c
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :
#
# End tag  : span
# Start tag: span
#      attr: ('class', 'ltx_author_notes')
# Start tag: span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_contact ltx_role_affiliation')
# Start tag: span
#      attr: ('id', 'm4')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(a)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : a
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :  Institute of Particle and Nuclear Physics, Faculty of Mathematics and Physics, Charles University, V Holešovičkách 2, 18000 Praha 8, Czech Republic
#
# Start tag: br
#      attr: ('class', 'ltx_break')
# Start tag: span
#      attr: ('id', 'm5')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(b)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : b
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :  INFN Sezione di Catania, Via Santa Sofia 64, I-95123 Catania, Italy
#
# Start tag: br
#      attr: ('class', 'ltx_break')
# Start tag: span
#      attr: ('id', 'm6')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', '{}^{(c)}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; vertical-align: 0.513em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : c
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :  Faculty of Physics, Institute of Theoretical Physics, University of Warsaw, Ul. Pasteura 5, 02-093, Warsaw, Poland
#
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_contact ltx_role_email')
# Start tag: a
#      attr: ('href', 'mailto:castorina@ct.infn.it')
# Data     : castorina@ct.infn.it
# End tag  : a
# Data     :
#
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_contact ltx_role_email')
# Start tag: a
#      attr: ('href', 'mailto:iorio@mff.cuni.cz')
# Data     : iorio@mff.cuni.cz
# End tag  : a
# Data     :
#
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_contact ltx_role_email')
# Start tag: a
#      attr: ('href', 'mailto:luca.smaldone@fuw.edu.pl')
# Data     : luca.smaldone@fuw.edu.pl
# End tag  : a
# Data     :
#
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     :
#
# End tag  : div
# Data     :
#
#
# Start tag: div
#      attr: ('class', 'ltx_abstract')
# Data     :
#
# Start tag: h6
#      attr: ('class', 'ltx_title ltx_title_abstract')
# Data     : Abstract
# End tag  : h6
# Data     :
#
# Start tag: p
#      attr: ('class', 'ltx_p')
# Data     : We take the view that the area of a black hole’s event horizon is quantized,
# Start tag: span
#      attr: ('id', 'm7')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'A=l_{P}^{2}\\,(4\\ln 2)\\,N')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.298em;')
# Data     : A
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo MJXc-space3')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.077em; padding-bottom: 0.298em;')
# Data     : =
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-msubsup MJXc-space3')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : l
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-stack')
#      attr: ('style', 'vertical-align: -0.327em;')
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; padding-bottom: 0.255em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mn')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.372em; padding-bottom: 0.372em;')
# Data     : 2
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sub')
#      attr: ('style', 'font-size: 70.7%; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.109em;')
# Data     : P
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mspace')
#      attr: ('style', 'width: 0.167em; height: 0px;')
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : (
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mn')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.372em; padding-bottom: 0.372em;')
# Data     : 4
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi MJXc-space1')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.372em; padding-bottom: 0.372em;')
# Data     : ln
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char')
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mn MJXc-space1')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.372em; padding-bottom: 0.372em;')
# Data     : 2
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.593em;')
# Data     : )
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mspace')
#      attr: ('style', 'width: 0.167em; height: 0px;')
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.085em;')
# Data     : N
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : , and the associated degrees of freedom are finite in number and of fermionic nature. We then investigate general aspects of the entropy,
# Start tag: span
#      attr: ('id', 'm8')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'S_{BH}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
#      attr: ('style', 'margin-right: -0.032em;')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.298em; padding-right: 0.032em;')
# Data     : S
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sub')
#      attr: ('style', 'font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : B
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.057em;')
# Data     : H
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : , our main focus being black-hole self-similarity. We first find a two-to-one map between the black hole’s configurations and the ordered partitions of the integer
# Start tag: span
#      attr: ('id', 'm9')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'N')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.085em;')
# Data     : N
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : . Hence we construct from there a composition law between the sub-parts making the whole configuration space. This gives meaning to black hole self-similarity, entirely within a single description, as a phenomenon stemming from the well known self-similarity of the ordered partitions of
# Start tag: span
#      attr: ('id', 'm10')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'N')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.085em;')
# Data     : N
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : . Finally, we compare the above to the well-known results on the subleading (quantum) corrections, that necessarily require different (quantum) statistical weights for the various configurations.
# End tag  : p
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: section
#      attr: ('id', 'S1')
#      attr: ('class', 'ltx_section')
# Data     :
#
# Start tag: h2
#      attr: ('class', 'ltx_title ltx_title_section')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_tag_section')
# Data     : I
# End tag  : span
# Data     : Introduction
# End tag  : h2
# Data     :
#
#
# Start tag: div
#      attr: ('id', 'S1.p1')
#      attr: ('class', 'ltx_para')
# Data     :
#
# Start tag: p
#      attr: ('class', 'ltx_p')
# Data     : In this paper we elaborate on the view that the entropy of a black hole,
# Start tag: span
#      attr: ('id', 'S1.p1.m1')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'S_{BH}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
#      attr: ('style', 'margin-right: -0.032em;')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.298em; padding-right: 0.032em;')
# Data     : S
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sub')
#      attr: ('style', 'font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : B
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.057em;')
# Data     : H
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Data     : , stems from the quantization of the area of the BH’s event horizon
# Start tag: cite
#      attr: ('class', 'ltx_cite ltx_citemacro_cite')
# Data     : [
# Start tag: a
#      attr: ('href', '#bib.bib3')
#      attr: ('title', '')
#      attr: ('class', 'ltx_ref')
# Data     : 3
# End tag  : a
# Data     : ,
# Start tag: a
#      attr: ('href', '#bib.bib4')
#      attr: ('title', '')
#      attr: ('class', 'ltx_ref')
# Data     : 4
# End tag  : a
# Data     : ,
# Start tag: a
#      attr: ('href', '#bib.bib5')
#      attr: ('title', '')
#      attr: ('class', 'ltx_ref')
# Data     : 5
# End tag  : a
# Data     : ]
# End tag  : cite
# End tag  : p
# Data     :
#
# Start tag: div
#      attr: ('class', 'ltx_engrafo_equation_container')
# Start tag: table
#      attr: ('id', 'S1.E1')
#      attr: ('class', 'ltx_equation ltx_eqn_table')
# Data     :
#
#
# Start tag: tbody
# Start tag: tr
#      attr: ('class', 'ltx_equation ltx_eqn_row ltx_align_baseline')
# Data     :
#
# Start tag: td
#      attr: ('class', 'ltx_eqn_cell ltx_eqn_center_padleft')
# End tag  : td
# Data     :
#
# Start tag: td
#      attr: ('class', 'ltx_eqn_cell ltx_align_center')
# Start tag: span
#      attr: ('id', 'S1.E1.m1')
#      attr: ('class', 'ltx_DisplayMath')
# Start tag: span
#      attr: ('class', 'mjpage mjpage__block')
# Start tag: span
#      attr: ('class', 'mjx-chtml MJXc-display')
#      attr: ('style', 'text-align: left;')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', ' A\\ =\\ \\alpha\\,N\\,l_{P}^{2}\\,, ')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.298em;')
# Data     : A
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mtext')
# Start tag: span
#      attr: ('class', 'mjx-char')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.225em;')
# Start tag: span
#      attr: ('class', 'mjx-charbox MJXc-font-inherit')
#      attr: ('style', 'font-size: 100%; padding-bottom: 0.3em; width: 0.5em;')
# Data     :
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo MJXc-space3')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.077em; padding-bottom: 0.298em;')
# Data     : =
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mtext MJXc-space3')
# Start tag: span
#      attr: ('class', 'mjx-char')
#      attr: ('style', 'padding-top: 0.519em; padding-bottom: 0.225em;')
# Start tag: span
#      attr: ('class', 'mjx-charbox MJXc-font-inherit')
#      attr: ('style', 'font-size: 100%; padding-bottom: 0.3em; width: 0.5em;')
# Data     :
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.225em; padding-bottom: 0.298em;')
# Data     : α
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mspace')
#      attr: ('style', 'width: 0.167em; height: 0px;')
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.085em;')
# Data     : N
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mspace')
#      attr: ('style', 'width: 0.167em; height: 0px;')
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-msubsup')
# Start tag: span
#      attr: ('class', 'mjx-base')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em;')
# Data     : l
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-stack')
#      attr: ('style', 'vertical-align: -0.327em;')
# Start tag: span
#      attr: ('class', 'mjx-sup')
#      attr: ('style', 'font-size: 70.7%; padding-bottom: 0.255em; padding-left: 0px; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mn')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'padding-top: 0.372em; padding-bottom: 0.372em;')
# Data     : 2
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-sub')
#      attr: ('style', 'font-size: 70.7%; padding-right: 0.071em;')
# Start tag: span
#      attr: ('class', 'mjx-texatom')
#      attr: ('style', '')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-math-I')
#      attr: ('style', 'padding-top: 0.446em; padding-bottom: 0.298em; padding-right: 0.109em;')
# Data     : P
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mspace')
#      attr: ('style', 'width: 0.167em; height: 0px;')
# End tag  : span
# Start tag: span
#      attr: ('class', 'mjx-mo')
# Start tag: span
#      attr: ('class', 'mjx-char MJXc-TeX-main-R')
#      attr: ('style', 'margin-top: -0.144em; padding-bottom: 0.519em;')
# Data     : ,
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : span
# End tag  : td
# Data     :
#
# Start tag: td
#      attr: ('class', 'ltx_eqn_cell ltx_eqn_center_padright')
# End tag  : td
# Data     :
#
# Start tag: td
#      attr: ('rowspan', '1')
#      attr: ('class', 'ltx_eqn_cell ltx_eqn_eqno ltx_align_middle ltx_align_right')
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_tag_equation ltx_align_right')
# Data     : (1)
# End tag  : span
# End tag  : td
# Data     :
#
# End tag  : tr
# Data     :
#
# End tag  : tbody
# End tag  : table
# End tag  : div
# Data     :
#
# Start tag: p
#      attr: ('class', 'ltx_p')
# Data     : where
# Start tag: span
#      attr: ('id', 'S1.p1.m2')
#      attr: ('class', 'ltx_Math')
# Start tag: span
#      attr: ('class', 'mjpage')
# Start tag: span
#      attr: ('class', 'mjx-chtml')
# Start tag: span
#      attr: ('class', 'mjx-math')
#      attr: ('aria-label', 'N\\in\\mathbb{N}')
# Start tag: span
#      attr: ('class', 'mjx-mrow')
#      attr: ('aria-hidden', 'true')
# Start tag: span
#      attr: ('class', 'mjx-mi')
# ...
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib13')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [13]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# A. Ashtekar, J. Baez, A. Corichi and K. Krasnov,
# Phys. Rev. Lett.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 80
# End tag  : span
# Data     :  (1998) 904.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib14')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [14]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# C. Rovelli,
#
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : Quantum gravity
# End tag  : span
# Data     : , (Cambridge University Press, Cambridge, 2004);
# C. Rovelli and F. Vidotto,
#
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : Covariant Loop Quantum Gravity : An Elementary Introduction to Quantum Gravity and Spinfoam Theory
# End tag  : span
# Data     : , (Cambridge University Press, Cambridge, 2014).
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib15')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [15]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# R. K. Kaul and P. Majumdar,
# Phys. Rev. Lett.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 84
# End tag  : span
# Data     :  (2000) 5255.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib16')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [16]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# K. S. Gupta and S. Sen,
# Phys. Lett. B
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 526
# End tag  : span
# Data     :  (2002) 121.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib17')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [17]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# A. Ghosh and P. Mitra,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 71
# End tag  : span
# Data     :  (2005) 027502.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib18')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [18]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# A. Majhi and P. Majumdar,
# Class. Quant. Grav.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 31
# End tag  : span
# Data     :  (2014) 195003.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib19')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [19]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# D. Singleton, E. C. Vagenas and T. Zhu,
# JHEP
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 05
# End tag  : span
# Data     :  (2014) 074 .
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib20')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [20]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# Y. C. Ong,
# Phys. Lett. B
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 785
# End tag  : span
# Data     :  (2018) 217.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib21')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [21]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# S. Lloyd,
# Nature
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 406
# End tag  : span
# Data     :  (2000) 1047.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib22')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [22]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# P. Shor,
# Proc. of the 35th Annual Symposium of the Foundations of Computer Science (IEEE, New York, 1994);
# SIAM J. Comput.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 26
# End tag  : span
# Data     :  (1997) 1484; arXiv:quant-ph/0005003.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib23')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [23]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# P. Giorda, A. Iorio, S. Sen, S. Sen, Phys. Rev. A
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 70
# End tag  : span
# Data     :  (2004) 032303.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib24')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [24]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# B. Harms and Y. Leblanc,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 46
# End tag  : span
# Data     :  (1992) 2334.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib25')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [25]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# B. Harms and Y. Leblanc,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 47
# End tag  : span
# Data     :  (1993) 2438.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib26')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [26]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# W. H. Huang,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 62
# End tag  : span
# Data     :  (2000) 043002.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib27')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [27]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# R. Hagedorn,
# Nuovo Cim. Suppl.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 3
# End tag  : span
# Data     :  (1965) 147.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib28')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [28]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# S. C. Frautschi,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 3
# End tag  : span
# Data     :  (1971) 2821.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib29')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [29]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :  W. Nahm,
# Nucl. Phys. B
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 54
# End tag  : span
# Data     :  (1972) 525.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib30')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [30]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# R.Hagedorn and J. Rafelski,
# Comm. Math.Phys.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 83
# End tag  : span
# Data     :  (1982) 563.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib31')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [31]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# S.W. Hawking,
# Nature
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 248
# End tag  : span
# Data     :  (1974) 30;
# Comm.  Math.  Phys.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 43
# End tag  : span
# Data     :  (1975) 199.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib32')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [32]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# G. Veneziano,
# in
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : Melting Hadrons, Boiling Quarks – From Hagedorn Temperature to Ultra-Relativistic Heavy-Ion
# Collisions at CERN
# End tag  : span
# Data     : , J. Rafelski ed., Springer open.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib33')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [33]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# L. Susskind, L. Thorlacius and J. Uglum,
# Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 48
# End tag  : span
# Data     :  (1993) 3743.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib34')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [34]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# L. Susskind and J. Lindesay,
#
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : An introduction to black holes, information, and the string theory revolution, The Holographic Universe
# End tag  : span
# Data     : ,( World Scientific, 2005).
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib35')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [35]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# N. Cabibbo and G. Parisi,
# Phys. Lett. B
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 59
# End tag  : span
# Data     :  (1975) 67.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib36')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [36]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# B. Zwiebach,
#
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : A first course in string theory
# End tag  : span
# Data     : , (Cambridge University Press, 2006).
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib37')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [37]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# P. Blanchard, S. Fortunato and H. Satz,
# Eur. Phys. J. C
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 34
# End tag  : span
# Data     :  (2004) 361.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib38')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [38]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# U. H. Danielsson and M. Schiffer, Phys. Rev. D
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 48
# End tag  : span
# Data     :  (1993) 4779.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib39')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [39]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# B. P. Abbott, R. Abbott , T. D. Abbott., M. B. Abernathy, F. Acernese, K. Ackley et al.,
# Phys. Rev. Lett.
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 116
# End tag  : span
# Data     :  (2016) 061102.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib40')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [40]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# G. Dvali and C. Gomez,
# Phys. Lett. B
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 716
# End tag  : span
# Data     :  (2012) 240.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib41')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [41]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :
# A. Czachor,
# Acta Phys. Pol. A
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_bold')
# Data     : 113
# End tag  : span
# Data     :  (2008) 1161.
#
#
# End tag  : span
# End tag  : li
# Start tag: li
#      attr: ('id', 'bib.bib42')
#      attr: ('class', 'ltx_bibitem')
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_tag ltx_role_refnum ltx_tag_bibitem')
# Data     : [42]
# End tag  : span
# Data     :
#
# Start tag: span
#      attr: ('class', 'ltx_bibblock')
# Data     :  M. Kac, in
# Start tag: span
#      attr: ('class', 'ltx_text ltx_font_italic')
# Data     : Statistical Physics, Phase Transitions and Superfluidity
# End tag  : span
# Data     : , Eds. M. Chretien, E. P. Gross, S. Desser, Vol. 1, Gordon and Breach, New York 1968,
# p. 241.
#
#
#
# End tag  : span
# Data     :
#
# End tag  : li
# Data     :
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# End tag  : section
# Data     :
#
# End tag  : article
# Data     :
#
# End tag  : div
# Data     :
#
# Start tag: footer
#      attr: ('class', 'ltx_page_footer')
# Data     :
#
# Start tag: div
#      attr: ('class', 'ltx_page_logo')
# Data     : Generated  by
# Start tag: a
#      attr: ('href', 'http://dlmf.nist.gov/LaTeXML/')
# Data     : LaTeXML
# Start tag: img
#      attr: ('src', 'data:image/png;base64,...')
#      attr: ('alt', '[LOGO]')
# End tag  : a
# Data     :
#
# End tag  : div
# End tag  : footer
# Data     :
#
# End tag  : div
# Data     :
#
#
#
# Start tag: script
#      attr: ('src', '/app/dist/javascript/index.js')
#      attr: ('type', 'text/javascript')
# End tag  : script
# End tag  : body
# End tag  : html

# %%
html_string
# Out:
# '<!DOCTYPE html><html><head>\n<title>Quantum black holes, partition of integers and self-similarity</title>\n<!--Generated by LaTeXML (version 0.8.4) http://dlmf.nist.gov/LaTeXML/.-->\n\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n<link rel="stylesheet" href="/app/dist/css/index.css" type="text/css">\n\n<meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"><style type="text/css">.mjx-chtml {display: inline-block; line-height: 0; text-indent: 0; text-align: left; text-transform: none; font-style: normal; font-weight: normal; font-size: 100%; font-size-adjust: none; letter-spacing: normal; word-wrap: normal; word-spacing: normal; white-space: nowrap; float: none; direction: ltr; max-width: none; max-height: none; min-width: 0; min-height: 0; border: 0; margin: 0; padding: 1px 0}\n.MJXc-display {display: block; text-align: center; margin: 1em 0; padding: 0}\n.mjx-chtml[tabindex]:focus, body :focus .mjx-chtml[tabindex] {display: inline-table}\n.mjx-full-width {text-align: center; display: table-cell!important; width: 10000em}\n.mjx-math {display: inline-block; border-collapse: separate; border-spacing: 0}\n.mjx-math * {display: inline-block; -webkit-box-sizing: content-box!important; -moz-box-sizing: content-box!important; box-sizing: content-box!important; text-align: left}\n.mjx-numerator {display: block; text-align: center}\n.mjx-denominator {display: block; text-align: center}\n.MJXc-stacked {height: 0; position: relative}\n.MJXc-stacked > * {position: absolute}\n.MJXc-bevelled > * {display: inline-block}\n.mjx-stack {display: inline-block}\n.mjx-op {display: block}\n.mjx-under {display: table-cell}\n.mjx-over {display: block}\n.mjx-over > * {padding-left: 0px!important; padding-right: 0px!important}\n.mjx-under > * {padding-left: 0px!important; padding-right: 0px!important}\n.mjx-stack > .mjx-sup {display: block}\n.mjx-stack > .mjx-sub {display: block}\n.mjx-prestack > .mjx-presup {display: block}\n.mjx-prestack > .mjx-presub {display: block}\n.mjx-delim-h > .mjx-char {display: inline-block}\n.mjx-surd {vertical-align: top}\n.mjx-mphantom * {visibility: hidden}\n.mjx-merror {background-color: #FFFF88; color: #CC0000; border: 1px solid #CC0000; padding: 2px 3px; font-style: normal; font-size: 90%}\n.mjx-annotation-xml {line-height: normal}\n.mjx-menclose > svg {fill: none; stroke: currentColor}\n.mjx-mtr {display: table-row}\n.mjx-mlabeledtr {display: table-row}\n.mjx-mtd {display: table-cell; text-align: center}\n.mjx-label {display: table-row}\n.mjx-box {display: inline-block}\n.mjx-block {display: block}\n.mjx-span {display: inline}\n.mjx-char {display: block; white-space: pre}\n.mjx-itable {display: inline-table; width: auto}\n.mjx-row {display: table-row}\n.mjx-cell {display: table-cell}\n.mjx-table {display: table; width: 100%}\n.mjx-line {display: block; height: 0}\n.mjx-strut {width: 0; padding-top: 1em}\n.mjx-vsize {width: 0}\n.MJXc-space1 {margin-left: .167em}\n.MJXc-space2 {margin-left: .222em}\n.MJXc-space3 {margin-left: .278em}\n.mjx-test.mjx-test-display {display: table!important}\n.mjx-test.mjx-test-inline {display: inline!important; margin-right: -1px}\n.mjx-test.mjx-test-default {display: block!important; clear: both}\n.mjx-ex-box {display: inline-block!important; position: absolute; overflow: hidden; min-height: 0; max-height: none; padding: 0; border: 0; margin: 0; width: 1px; height: 60ex}\n.mjx-test-inline .mjx-left-box {display: inline-block; width: 0; float: left}\n.mjx-test-inline .mjx-right-box {display: inline-block; width: 0; float: right}\n.mjx-test-display .mjx-right-box {display: table-cell!important; width: 10000em!important; min-width: 0; max-width: none; padding: 0; border: 0; margin: 0}\n.MJXc-TeX-unknown-R {font-family: monospace; font-style: normal; font-weight: normal}\n.MJXc-TeX-unknown-I {font-family: monospace; font-style: italic; font-weight: normal}\n.MJXc-TeX-unknown-B {font-family: monospace; font-style: normal; font-weight: bo ...
